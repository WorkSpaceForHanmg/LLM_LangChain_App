# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# 1단계: PDF 문서 로드 및 분할
pdf_path = "../data/콘텐츠분쟁해결_사례.pdf"
loader = PyPDFLoader(pdf_path)
documents = loader.load()  # 페이지별 Document 리스트

# 텍스트 분할기 설정 (법률 사례 최적화)
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,         #  법률 사례는 1200-1800자 권장
    chunk_overlap=300,       #  사례 맥락 보존을 위해 200-400자
    separators=[
        "\n【사건개요】",       #  법률 문서 섹션 구분자
        "\n【쟁점사항】",       #  쟁점 부분 구분
        "\n【처리경위】",       #  처리 과정 구분
        "\n【처리결과】",       #  결과 부분 구분
        "\n■", "\n\n", "\n", ".", " ", ""
    ]
)

texts = text_splitter.split_documents(documents)  # 문서 분할 후 리스트

print(f"총 분할된 문서 조각 수: {len(texts)}")  # 확인용 출력
# Out:
# 총 분할된 문서 조각 수: 104

# %%
# 2단계: 임베딩 모델 설정
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",  #  한국어 법률 용어에 최적
    dimensions=1536                  #  고성능 임베딩 차원
)
# Out:
# c:\Users\user\AppData\Local\pypoetry\Cache\virtualenvs\langchain-basic-kGdHTiMZ-py3.12\Lib\site-packages\langchain_community\embeddings\openai.py:271: UserWarning: WARNING! dimensions is not default parameter.
#                     dimensions was transferred to model_kwargs.
#                     Please confirm that dimensions is what you intended.
#   warnings.warn(

# %%
# 3단계: 벡터 저장소 생성 및 검색기 설정
vectorstore = FAISS.from_documents(texts, embeddings)
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

# %%
# 4단계: LLM 설정
llm = ChatOpenAI(
    model="gpt-4o",         #  또는 "gpt-4o-mini" (경제적)
    temperature=0.2,        #  법률 조언은 정확성 중시
    max_tokens=2000         #  충분한 답변 길이
)

# %%
# 5단계: 법률 자문 프롬프트 작성
prompt_template = """
당신은 콘텐츠 분야 전문 법률 자문사입니다. 
아래 분쟁조정 사례들을 바탕으로 정확하고 전문적인 법률 조언을 제공해주세요.

관련 분쟁사례:
{context}

상담 내용: {question}

답변 가이드라인:
1. 제시된 사례들을 근거로 답변하세요                
2. 관련 법령이나 조항이 있다면 명시하세요
3. 비슷한 사례의 처리경위와 결과를 참고하여 설명하세요
4. 실무적 해결방안을 단계별로 제시하세요
5. 사례에 없는 내용은 "제시된 사례집에서는 확인할 수 없습니다"라고 명시하세요

전문 법률 조언:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)

# %%
# 6단계: QA 체인 생성
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,                                     #  위에서 설정한 LLM
    chain_type="stuff",                          #  문서들을 하나로 합쳐서 처리
    retriever=retriever,                         #  위에서 설정한 검색기
    chain_type_kwargs={"prompt": prompt},        #  법률 자문 프롬프트
    return_source_documents=True                 #  참조 문서도 함께 반환
)

# %%
# 7단계:  테스트 질문 작성성
test_questions = [
    "온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?",
    "인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?",
    "무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?",
    "미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?",
    "온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?"
]

# %%
# 8단계: 테스트 질문 예시 및 실행
def classify_dispute_type(query):
    game_keywords = ["게임", "아이템", "계정", "캐릭터", "레벨", "길드", "온라인게임"]
    elearning_keywords = ["강의", "온라인교육", "이러닝", "수강", "환불", "화상교육"]
    web_keywords = ["웹사이트", "무료체험", "자동결제", "구독", "사이트"]
    
    query_lower = query.lower()
    
    if any(keyword in query_lower for keyword in game_keywords):
        return "게임"
    elif any(keyword in query_lower for keyword in elearning_keywords):
        return "이러닝"
    elif any(keyword in query_lower for keyword in web_keywords):
        return "웹콘텐츠"
    else:
        return "기타"

for question in test_questions:
    dispute_type = classify_dispute_type(question)
    print(f"\n분쟁 유형: {dispute_type}")
    print(f"질문: {question}")
    result = qa_chain({"query": question})  # 키는 'query' 또는 'question'으로 테스트
    print(f"답변: {result['result']}\n")
    
    print("참조 문서 예시:")
    for doc in result['source_documents'][:2]:  # 상위 2개 문서만 출력
        print(doc.page_content[:300], "...\n")
# Out:
# 분쟁 유형: 게임
# 질문: 온라인 게임에서 시스템 오류로 아이템이 사라졌는데, 게임회사가 복구를 거부하고 있습니다. 어떻게 해결할 수 있나요?
# 답변: 온라인 게임에서 시스템 오류로 인해 아이템이 사라진 경우, 게임회사가 복구를 거부하는 상황에 대한 법률적 조언을 드리겠습니다. 제시된 사례들을 근거로 다음과 같이 답변드립니다.
#
# 1. **사례 분석**:
#    - **사례 1 (2006년)**: 시스템 오류로 아이템이 소멸된 경우, 계정 명의자가 아닌 신청인의 복구 요청은 거부되었습니다. 계정 명의자가 직접 복구 신청을 해야 한다는 점이 강조되었습니다.
#    - **사례 2 (2009년)**: 시스템 오류로 인한 게임머니 소실 주장에 대해, 시스템 오류가 발생하지 않았다는 게임사의 입장이 있었습니다. 신청인의 통신회선 문제일 가능성이 제기되었습니다.
#    - **사례 3 (2009년)**: 해킹으로 인한 아이템 손실의 경우, 보안서비스 미사용으로 인해 복구가 거부되었습니다.
#    - **사례 4 (2007년)**: 해킹 아이템 회수와 관련하여, 게임머니 환급으로 신청인의 피해가 없다고 판단되었습니다.
#    - **사례 5 (2008년)**: 보안서비스 미작동으로 인한 아이템 도난의 경우, 게임사가 도난을 인정하고 아이템을 복구해 주었습니다.
#
# 2. **관련 법령 및 조항**:
#    - 민법 제250조 및 제251조는 도품이나 유실물에 대한 반환 청구에 관한 규정을 두고 있습니다. 그러나 이는 주로 물리적 재산에 대한 규정이며, 디지털 아이템에 직접 적용되지는 않습니다.
#
# 3. **실무적 해결방안**:
#    - **계정 명의 확인**: 계정 명의자가 본인인지 확인하고, 명의자가 아닌 경우 명의자에게 복구 신청을 요청합니다.
#    - **증거 수집**: 시스템 오류로 인한 아이템 소실을 입증할 수 있는 증거(스크린샷, 로그 기록 등)를 수집합니다.
#    - **게임사와의 협의**: 게임사의 고객센터에 공식적으로 이의를 제기하고, 시스템 오류에 대한 구체적인 설명과 복구 요청을 합니다.
#    - **소비자 보호 기관에 문의**: 한국소비자원 등 관련 기관에 상담을 요청하여 중재를 시도할 수 있습니다.
#    - **법적 조치 고려**: 위의 방법으로 해결되지 않을 경우, 법적 조치를 고려할 수 있으며, 이 경우 전문 변호사의 상담을 받는 것이 좋습니다.
#
# 4. **추가 정보**:
#    - 제시된 사례집에서는 시스템 오류로 인한 아이템 소실에 대한 법적 판례나 구체적인 법령 적용 사례는 확인할 수 없습니다.
#
# 이와 같은 단계별 접근을 통해 문제를 해결해 나가시길 권장드립니다.
#
# 참조 문서 예시:
# 1. 게임
# 3
# 게임1
# ■ 1-가-1) 한국소비자원 조정전 상담사례2006_시스템 오류로 소멸된 아이템 복구 요구【사건개요】신청인은 피신청인이 제공하는 온라인게임서비스를 이용하던 중 시스템 오류로 120,000원 상당의 아이템이 소멸되었고, 이에 피신청인에게 수차례 이의제기하였으나 사과 공지문만 안내 되고 아이템이 복구 되지 않았다. 피신청인이 정상적으로 거래하던 중 아이템이 소멸된 것을 확인해 주었으나 규정상 복구가 불가하다는 답변을 한 것에 대하여 신청인은 정상적으로 이용하다 시스템 오류로 인해 소멸된 아이템에 대해 원상복구를 요 ...
#
# 1. 게임
# 23
# ■ 1-가-1) 한국소비자원 조정전 상담사례2009_시스템 오류로 인한 손실 아이템 복구 요구【사건개요】신청인은 2009. 9. 4 피신청인 프로그램 업데이트 후 2009. 9. 5 온라인게임 서비스를 이용하다 렉(시스템오류)발생으로 며칠간 오류현상이 반복되더니 신청인의 게임머니 1,000억 가량이 소실된 것을 확인 한 뒤, 피신청인 시스템의 오류로 인한 게임머니 소실이므로 조속히 환급할 것을 주장하였다.【쟁점사항】시스템 오류 발생 여부【처리경위】동 건은 렉(시스템 오류)으로 인해 신청인 게임머니 약 1,000억 소 ...
#
#
# 분쟁 유형: 이러닝
# 질문: 인터넷 강의를 중도 해지하려고 하는데 과도한 위약금을 요구받고 있습니다. 정당한가요?
# 답변: 인터넷 강의를 중도 해지하려고 할 때 과도한 위약금을 요구받는 경우, 다음과 같은 법률적 조언을 드릴 수 있습니다.
#
# 1. **관련 법령 및 기준**:
#    - **방문판매 등에 관한 법률 제29조**: 계약의 해지에 관한 규정을 포함하고 있으며, 계약 해지 시 위약금의 부과 기준을 명시하고 있습니다.
#    - **소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)**: 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%를 공제 후 환급하도록 규정하고 있습니다.
#
# 2. **사례 분석**:
#    - **2007년 사례**: 피신청인이 과도한 위약금을 공제하려 했으나, 소비자분쟁해결기준에 따라 해지일까지의 이용일수에 해당하는 금액과 총 이용금액의 10%만 공제 후 환급해야 한다고 결정되었습니다.
#    - **2008년 사례**: 신청인이 강의를 수강하지 않았음에도 불구하고, 피신청인은 환불 불가를 주장했으나, 결국 이용일수와 총 이용금액의 10%를 공제한 금액을 환불하기로 조정되었습니다.
#    - **2010년 사례**: 화상불량으로 인한 중도 해지 시, 실제 이용일수를 기준으로 환급이 이루어졌습니다.
#
# 3. **실무적 해결방안**:
#    - **계약서 확인**: 먼저 계약서에 명시된 해지 및 환불 조건을 확인하세요. 계약서에 명시된 조건이 법령 및 소비자분쟁해결기준과 상충되는 경우, 후자가 우선 적용될 수 있습니다.
#    - **해지 의사 명확히 전달**: 계약 해지 의사를 서면으로 명확히 전달하고, 해지일까지의 이용일수를 기록해 두세요.
#    - **소비자분쟁조정위원회에 조정 신청**: 위약금이 과도하다고 판단될 경우, 소비자분쟁조정위원회에 조정을 신청하여 중재를 받을 수 있습니다.
#    - **법적 자문**: 필요시 변호사와 상담하여 법적 대응 방안을 모색하세요.
#
# 4. **제시된 사례집에서는 확인할 수 없는 내용**:
#    - 특정 계약의 세부 조건이나 당사자 간의 구체적인 합의 내용은 제시된 사례집에서는 확인할 수 없습니다. 계약서 및 관련 문서를 직접 검토하는 것이 필요합니다.
#
# 이러한 조언을 바탕으로, 귀하의 상황에 맞는 적절한 대응을 하시기 바랍니다.
#
# 참조 문서 예시:
# . 이러닝·······························································································5 1가. 한국소비자원2007_온라인통신교육서비스 대금 환급 요구···················································5 32007_온라인통신교육서비스 대금 환급 요구2·················································5 52007_인터넷교육서비스 중도해지 요구············ ...
#
# 2. 이러닝
# 57
# ■ 2-가 한국소비자원 조정결정례2007_인터넷교육서비스 중도해지 요구【사건개요】청구인은 2006. 2. 8. 피청구인이 운영하는 인터넷교육서비스를 청구인의 자녀가 1년간 이용하기로 약정하고 1,740,000원을 지급하였으나 서비스 내용에 불만이 있어 같은 해 5. 3. 계약해지를 요청하고 적정 금액의 환급을 요구하였다. 피청구인은 청구인이 지급한 1,740,000원에서 위약금, 월교육비 및 화상교육비, 가입비, 사은품 비용 등 1,632,000원을 공제하고 환급해 줄 수 있다고 하여 분쟁이 발생하게 되었다.【쟁점 ...
#
#
# 분쟁 유형: 이러닝
# 질문: 무료체험 후 자동으로 유료전환되어 요금이 청구되었습니다. 환불 가능한가요?
# 답변: 무료체험 후 자동으로 유료 전환되어 요금이 청구된 경우, 환불 가능 여부에 대한 법률 조언은 다음과 같습니다:
#
# 1. **계약의 중요 내용 명시 및 고지 의무**:
#    - 제시된 사례들에서 공통적으로 문제되는 부분은 계약 체결 시 중요한 내용을 명확히 고지하지 않았다는 점입니다. 특히, 무료 체험 후 자동으로 유료 전환된다는 사실이 소비자에게 명확히 전달되지 않았을 경우, 이는 「약관의 규제에 관한 법률」 제3조에 따른 약관의 작성 및 설명의무 위반으로 볼 수 있습니다.
#
# 2. **소비자 보호 관련 법령**:
#    - 「소비자기본법」에 따른 소비자분쟁해결기준에 따르면, 소비자가 계약의 중요한 내용을 충분히 인지하지 못한 상태에서 체결된 계약은 무효화될 수 있습니다.
#    - 또한, 「방문판매 등에 관한 법률」 제29조에 따라 소비자는 언제든지 계약을 해지할 수 있으며, 해지 시 잔여 이용요금을 환급받을 권리가 있습니다.
#
# 3. **비슷한 사례의 처리경위와 결과**:
#    - 제시된 사례들에서는 소비자가 계약 해지 의사를 명확히 통지한 경우, 피신청인이 잔여 이용요금을 환급하도록 조정되었습니다. 특히, 계약 해지 의사를 내용증명 우편 등으로 명확히 전달한 경우, 적법하게 해지된 것으로 인정되었습니다.
#
# 4. **실무적 해결방안**:
#    - **1단계**: 계약 체결 시 중요한 내용이 명확히 고지되지 않았음을 근거로 계약 해지를 요청합니다.
#    - **2단계**: 계약 해지 의사를 내용증명 우편 등을 통해 명확히 통지합니다.
#    - **3단계**: 환불 요청 시, 잔여 이용요금에서 이용한 서비스에 대한 요금과 위약금(일반적으로 10%)을 제외한 금액을 환급받을 수 있도록 요구합니다.
#    - **4단계**: 피신청인이 환불을 거부할 경우, 한국소비자원이나 전자거래분쟁조정위원회에 조정을 신청할 수 있습니다.
#
# 5. **추가적인 내용**:
#    - 제시된 사례집에서는 확인할 수 없는 내용이 있을 수 있습니다. 예를 들어, 특정 서비스의 약관 세부 내용이나 개별 소비자의 계약 체결 과정에 대한 구체적인 정보는 사례집에 포함되지 않았을 수 있습니다.
#
# 이와 같은 절차를 통해 소비자는 자신의 권리를 보호받을 수 있으며, 불합리한 계약 조건으로 인한 피해를 최소화할 수 있습니다.
#
# 참조 문서 예시:
# 3. 기타(웹)
# 95
# ■ 3-가 한국소비자원 조정결정례2010_무료 이벤트 후 자동 소액 결제 요금 환급요구【사건개요】신청인은 2008. 12. 29. 피신청인 1이 운영하는 음악 다운로드 사이트 '003'의 무료이벤트(이벤트명 : '003' 7일 무료체험이벤트)에 참여하여 회원가입을 하였다. 그러나 2008. 1.부터 본인동의 없이 유료 회원으로 자동 가입되어 매달 7,700원이 결제된 것을 2008. 5.인지하게 되어 지불대행업체인 피신청인 2를 통해 이의제의제기를 하여 5월분 이용료를 청구취소하였고, 그 후 피신청인 1을 상대 ...
#
# 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 -
# 64
# 사용하여 반환받을 수 있는 서비스가 아니므로 미 이용기간에 해당하는 대금을 환급해 줄 수 없다고 주장하나, 피신청인의 ‘이용자가 서비스 이용 계약을 체결한 후에 이용자는 임의적으로 해지 신청을 할 수 없다’는 약관 내용은「약관의 규제에 관한 법률」제9조(계약의 해제·해지)에 따라 법률의 규정에 의한 고객의 해제권 또는 해지권을 배제하거나 그 행사를 제한하는 조항으로 무효라고 할 것이다. 이 사건 계약은 「방문판매 등에 관한 법률」제2조 제8호의 계속거래로서 같은 법 제 ...
#
#
# 분쟁 유형: 게임
# 질문: 미성년자가 부모 동의 없이 게임 아이템을 구매했습니다. 환불받을 수 있는 방법이 있나요?
# 답변: 미성년자가 부모의 동의 없이 게임 아이템을 구매한 경우, 환불을 받을 수 있는 가능성은 여러 요소에 따라 달라질 수 있습니다. 제시된 사례들을 바탕으로 다음과 같은 법률 조언을 드립니다.
#
# 1. **관련 법령 및 조항**:
#    - **민법 제5조**: 미성년자의 능력에 관한 규정으로, 미성년자는 법정대리인의 동의 없이 법률 행위를 할 수 없습니다.
#    - **민법 제17조**: 무능력자의 사술에 관한 규정으로, 미성년자가 사술로써 능력자임을 믿게 한 경우에는 그 행위를 취소할 수 없습니다.
#    - **민법 제741조**: 부당이득의 내용으로, 계약 없이 결제를 받았다면 이는 부당이득으로서 반환의 대상이 됩니다.
#
# 2. **사례 분석**:
#    - **사례 1**: 미성년자가 타인의 명의를 도용하여 결제한 경우, 이는 부당이득으로 볼 수 있으며, 환불이 가능할 수 있습니다. 그러나, 피신청인이 실명 인증 절차를 거쳤고, 장기간에 걸쳐 결제가 이루어진 점을 들어 환불이 어려움을 주장한 사례입니다.
#    - **사례 2**: 미성년자가 부모의 신용카드를 사용하여 결제한 경우, 사술을 사용한 것으로 판단되어 취소권을 행사할 수 없다는 결론이 내려졌습니다. 다만, 구매한 게임머니를 반환하는 경우 환불이 가능하다는 조건이 제시되었습니다.
#
# 3. **실무적 해결방안**:
#    - **1단계**: 구매 내역 및 결제 수단을 확인합니다. 미성년자가 타인의 명의를 도용했거나 부모의 신용카드를 사용한 경우, 해당 사실을 입증할 수 있는 자료를 준비합니다.
#    - **2단계**: 게임사에 환불 요청을 합니다. 이때, 미성년자의 법률 행위가 법정대리인의 동의 없이 이루어졌음을 강조하고, 관련 법령을 근거로 환불을 요청합니다.
#    - **3단계**: 게임사가 환불을 거부할 경우, 전자거래분쟁조정위원회에 조정을 신청할 수 있습니다. 이때, 미성년자가 사술을 사용하지 않았음을 입증할 수 있는 자료를 제출합니다.
#    - **4단계**: 구매한 아이템이나 게임머니를 반환할 수 있는 경우, 이를 게임사에 반환하고 환불을 요청하는 방안을 고려합니다.
#
# 4. **추가적인 조언**:
#    - 만약 미성년자가 사술을 사용하여 능력자임을 믿게 한 경우, 환불이 어려울 수 있습니다. 이러한 경우에는 법률 전문가의 도움을 받아 추가적인 법적 조치를 고려해야 할 수 있습니다.
#
# 제시된 사례집에서는 위와 같은 상황에 대한 구체적인 해결 방안을 확인할 수 없습니다. 추가적인 법률 상담이 필요할 수 있습니다.
#
# 참조 문서 예시:
# 1. 게임
# 45
# ■ 1-나 전자거래분쟁조정위원회 조정결정례2008_부당결제대금 반환 청구【사건개요】신청인의 자녀는 2004. 4. 22. 피신청인이 운영하는 게임 사이트에 가명으로 타인(성인)의 주민번호를 이용하여 회원가입을 한 뒤 2007. 9. ∼ 2007.12. 까지 해당게임을 이용하면서 아이템 구입을 위해 총 18회에 걸쳐 284,900원을 집전화로 결제하였다. 이 사실을 알게 된 신청인은 자녀의 최초가입시점에는 주민번호만 맞으면 가입이 가능하였다고 하나, 3년 5개월이 지난 뒤 다시 게임을 이용하였을 시에는 실명확인절차를  ...
#
# 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 -
# 48
#  - 피신청인  ㆍ 피신청인은 구매당시 구매자에게 전화를 하였을 당시 전화를 받은 자는 자신을 24세의 남성으로 카드명의자의 아들이라 소개하며 문제가 없음을 몇 번이나 이야기 하였고, 구매 금액이 과다하여 24.∼25. 통화확인 시에도 같은 주장을 하여 음성 확인 시 성년이라 짐작하여 온라인 게임머니를 양도 하였고, 또 인터넷에서 신용카드사용 시 카드번호, CVS번호, 안심클릭 비밀번호, isp 비밀번호 등 4중 보안장치가 되어있어 부모님 몰래 미성년자가 사용했다고 믿 ...
#
#
# 분쟁 유형: 기타
# 질문: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶습니다. 가능한가요?
# 답변: 온라인 교육 서비스가 광고와 다르게 제공되어 계약을 해지하고 싶다는 문의에 대해 다음과 같이 답변드리겠습니다.
#
# 1. **관련 법령 및 조항**:
#    - 방문판매 등에 관한 법률 제29조: 계약의 해지
#    - 방문판매 등에 관한 법률 제30조: 계약의 해지 또는 해제의 효과와 위약금 등
#    - 소비자기본법에 따른 소비자분쟁해결기준(공정위고시, 인터넷콘텐츠업)
#
# 2. **비슷한 사례의 처리경위 및 결과**:
#    - **사례 1**: 2008년 온라인 동영상 강의 계약 해지 청구 사례에서는, 신청인이 강의를 수강하지 않았음에도 불구하고 청약철회 기간이 지났다는 이유로 환불이 거부되었습니다. 그러나 조정 과정에서 상호 양보를 통해 일부 환불이 이루어졌습니다.
#    - **사례 2**: 2007년 인터넷교육서비스 중도해지 요구 사례에서는, 피청구인이 과도한 위약금을 공제하려 했으나, 소비자피해보상규정에 따라 적정 금액만 공제 후 환급이 이루어졌습니다.
#    - **사례 3**: 2010년 온라인교육 서비스 계약 해지에 따른 이용요금 환급 요구 사례에서는, 계약 해지가 적법하게 이루어졌고, 과도한 위약금 공제가 부당하다는 판단 하에 적정한 환급이 이루어졌습니다.
#
# 3. **실무적 해결방안**:
#    - **1단계**: 계약서 및 약관 확인 - 계약서와 약관에 명시된 환불 및 해지 조건을 확인하세요.
#    - **2단계**: 증거 수집 - 광고와 실제 제공된 서비스 간의 차이를 입증할 수 있는 자료(예: 광고 내용, 실제 서비스 내용)를 수집하세요.
#    - **3단계**: 사업자와 협상 - 수집한 증거를 바탕으로 사업자에게 계약 해지 및 환불을 요청하세요. 이때, 소비자분쟁해결기준에 따른 적정 환급을 요구할 수 있습니다.
#    - **4단계**: 분쟁조정 신청 - 협상이 결렬될 경우, 한국소비자원이나 전자거래분쟁조정위원회에 분쟁조정을 신청할 수 있습니다.
#
# 4. **기타**:
#    - 제시된 사례집에서는 광고와 실제 서비스 간의 차이로 인한 계약 해지에 대한 구체적인 사례는 확인할 수 없습니다. 그러나 일반적인 소비자 보호 원칙에 따라, 광고와 다르게 제공된 서비스는 계약 해지 및 환불의 사유가 될 수 있습니다.
#
# 이와 같은 절차를 통해 문제를 해결하시기 바랍니다. 추가적인 법률 자문이 필요하시면 전문가와 상담하시기를 권장드립니다.
#
# 참조 문서 예시:
# 콘텐츠분쟁조정 법리 연구 2부 - 타 분쟁조정사례 조사 -
# 88
# ■ 2-다 전자거래분쟁조정위원회 조정결정례2008_온라인 동영상 강의 계약 해지 청구【사건개요】신청인은 2008. 4. 2. 피신청인의 사이트에서 강의기간 120일 일시정지 30일을 계약내용으로 하는 온라인 강좌를 2008. 4. 12일부터 시작하기로 458,500원에 계약하였다. 그러나 신청인 개인의 사정으로 강의 시작일을 연기하였다. 5. 12.이후로도 강의를 듣지 못한 신청인은 2008. 6. 23. 피신청인 사이트 Q&A게시판을 통해 계약 해지 의사를 표명하였으 ...
#
# 2. 이러닝
# 89
# 상기 내용을 살펴보면, 신청인은 청약철회 기간을 지났으므로 위 계약의 청약을 철회할 수는 없는 것으로 보인다. 피신청인은 위 계약에 따라 정해진 기간 내에 신청인이 접근하여 온라인 강좌를 수강할 수 있는 여건을 제공하는 등 피신청인의 계약상 의무는 이행된 것으로 보이며, 피신청인의 약관에 따른 환불기준에 의하더라도 신청인은 환불에 필요한 요건을 충족하지 못하여 신청인은 계약상 위 계약을 해지 할 수 있는 법적권한이 없다 하겠다.다만, 피신청인의 환불기준이 웹사이트에서 Q&A 방식으로 제공되고 있어 신청인 등이 쉽게 ...
